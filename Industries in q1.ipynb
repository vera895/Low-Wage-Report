# %%
import pandas as pd
q1 = pd.read_csv('C:/Users/Yutin/Desktop/Low_wage_report/q1_obs_22033 .csv')

# %%
#22033 obs in q1
ind_q1 = q1.IND.value_counts()
ind_q1 = pd.DataFrame(ind_q1)
ind_q1.columns = ['IND_detail']
ind_q1['IND_perecnt_%'] = ind_q1.IND_detail/22033*100
ind_q1
# Out:
#       IND_detail  IND_perecnt_%
# 8680        3493      15.853492
# 770         1671       7.584078
# 4970        1014       4.602188
# 6170         755       3.426678
# 7690         580       2.632415
# 5380         538       2.441792
# 7770         509       2.310171
# 7860         459       2.083239
# 8980         401       1.819997
# 5170         382       1.733763
# 4470         358       1.624835
# 6380         335       1.520447
# 8190         305       1.384287
# 6180         302       1.370671
# 7580         269       1.220896
# 7680         265       1.202741
# 8590         262       1.189125
# 8660         242       1.098352
# 9470         241       1.093814
# 4670         239       1.084737
# 6390         233       1.057505
# 8270         212       0.962193
# 4870         208       0.944038
# 8770         173       0.785186
# 3490         167       0.757954
# 7070         167       0.757954
# 7870         166       0.753415
# 6190         159       0.721645
# ...

# %%
ind_q1.to_csv('C:/Users/Yutin/Desktop/Low_wage_report/ind_q1.csv')
