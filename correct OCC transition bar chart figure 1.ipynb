# %%
import pandas as pd
q1 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q1.csv')
q2 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q2.csv')
q3 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q3.csv')
q4 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q4.csv')

# %%
df = pd.concat([q1,q2,q3,q4])

# %%
df
# 7844
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 0           3648          3648          306601  2010   16894      3      NaN
# 1           3650          3650          306603  2010   16895      3      NaN
# 2           3652          3652          306605  2010   16896      3      NaN
# 3           3654          3654          306607  2010   16898      3      NaN
# 4           3660          3660          306613  2010   16901      3      NaN
# 5           3669          3669          306622  2010   16908      3      NaN
# 6           3672          3672          306625  2010   16908      3      NaN
# 7           3675          3675          306628  2010   16910      3      NaN
# 8           3684          3684          306637  2010   16918      3      NaN
# 9           3685          3685          306638  2010   16918      3      NaN
# 10          3691          3691          306644  2010   16921      3      NaN
# ...

# %%
occ_list = pd.read_excel('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q1_q4_occ_list_correct.xlsx')

# %%
occ_list
# Out:
#     OCC_q1  quality_index  OCC_q2  quality_index.1  OCC_q3  quality_index.2  \
# 0      135      -2.172969    20.0        -0.257486    10.0         0.580464
# 1      840      -4.558480   220.0        -0.942731    40.0         0.548583
# 2     1740      -3.020935   310.0        -1.216517   136.0         0.937961
# 3     2810      -1.572939   940.0        -0.861913   150.0         0.483609
# 4     2840      -1.533714  1820.0        -0.910752   160.0         0.461447
# 5     3060      -1.520796  2160.0        -0.433067   410.0        -0.120957
# 6     3250      -3.070959  2440.0        -0.838441   420.0         0.185918
# 7     3930      -4.056901  3030.0        -0.212814   540.0         0.973251
# 8     3940      -4.844852  3600.0        -1.176428   565.0         0.738016
# 9     4000      -1.823410  3800.0        -0.812192   600.0         0.364821
# 10    4020      -2.270603  3910.0        -0.919616   640.0         1.194453
# ...

# %%
#  Q1 obs pick up, Last Year OCC = Q1
OCC_q1 = occ_list['OCC_q1']
OCC_q1 = pd.DataFrame(OCC_q1)
OCC_q1 = list(OCC_q1.values.flatten())
OCC_q1
q1_ob = df.loc[df['OCCLY'].isin(OCC_q1)]

# %%
#  Q2 obs pick up
OCC_q2 = occ_list['OCC_q2']
OCC_q2 = pd.DataFrame(OCC_q2)
OCC_q2 = list(OCC_q2.values.flatten())
OCC_q2
q2_ob = df.loc[df['OCCLY'].isin(OCC_q2)]

# %%
#  Q3 obs pick up
OCC_q3 = occ_list['OCC_q3']
OCC_q3 = pd.DataFrame(OCC_q3)
OCC_q3 = list(OCC_q3.values.flatten())
OCC_q3
q3_ob = df.loc[df['OCCLY'].isin(OCC_q3)]

# %%
#  Q4 obs pick up
OCC_q4 = occ_list['OCC_q4']
OCC_q4 = pd.DataFrame(OCC_q4)
OCC_q4 = list(OCC_q4.values.flatten())
OCC_q4
q4_ob = df.loc[df['OCCLY'].isin(OCC_q4)]

# %%
q1_ob['LastYearOCC']='q1'
q2_ob['LastYearOCC']='q2'
q3_ob['LastYearOCC']='q3'
q4_ob['LastYearOCC']='q4'
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data = pd.concat([q1_ob, q2_ob, q3_ob, q4_ob])

# %%
data
# 7844
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 1           3650          3650          306603  2010   16895      3      NaN
# 2           3652          3652          306605  2010   16896      3      NaN
# 4           3660          3660          306613  2010   16901      3      NaN
# 6           3672          3672          306625  2010   16908      3      NaN
# 8           3684          3684          306637  2010   16918      3      NaN
# 10          3691          3691          306644  2010   16921      3      NaN
# 12          3712          3712          306665  2010   16931      3      NaN
# 13          3718          3718          306671  2010   16935      3      NaN
# 14          3748          3748          306701  2010   16942      3      NaN
# 16          3754          3754          306707  2010   16943      3      NaN
# 17          3755          3755          306708  2010   16943      3      NaN
# ...

# %%
data.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Correct_Figure1/Last_year_occ_q1_q4.csv')

# %% [markdown]
# # Transition Analysis

# %%
len(data[data['EMPSTAT'].notna()])
# Out:
# 7844

# %%
len(data[data['OCC'].notna()])
# Out:
# 7844

# %%
len(data[data['OCCLY'].notna()])
# Out:
# 7844

# %%
data['count']=[1]*len(data)

# %%
# out of labor force:
nilf = data[data['EMPSTAT'].isin([30,31,32,33,34,35,36])]
len(nilf)
# Out:
# 357

# %%
nilf
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 25          3834          3834          308290  2010   17635      3      NaN
# 65          4145          4145          308681  2010   17823      3      NaN
# 73          4318          4318          308854  2010   17895      3      NaN
# 80          4389          4389          308925  2010   17921      3      NaN
# 82          4419          4419          308955  2010   17934      3      NaN
# 87          4449          4449          308985  2010   17945      3      NaN
# 112         4724          4724          309260  2010   18052      3      NaN
# 119         4846          4846          309382  2010   18106      3      NaN
# 161         5380          5380          309916  2010   18363      3      NaN
# 176         5516          5516          310052  2010   18460      3      NaN
# 180         5540          5540          310076  2010   18479      3      NaN
# ...

# %%
nilf.groupby('LastYearOCC')['count'].sum()
# Out:
# LastYearOCC
# q1    180
# q2     85
# q3     43
# q4     49
# Name: count, dtype: int64

# %%
# Unemployed
unem = data[data['EMPSTAT'].isin([20,21,22])]

# %%
unem
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 31          3911          3911          308367  2010   17676      3      NaN
# 35          3928          3928          308384  2010   17683      3      NaN
# 46          4009          4009          308545  2010   17751      3      NaN
# 81          4395          4395          308931  2010   17924      3      NaN
# 104         4598          4598          309134  2010   18006      3      NaN
# 110         4676          4676          309212  2010   18038      3      NaN
# 132         5061          5061          309597  2010   18202      3      NaN
# 144         5162          5162          309698  2010   18243      3      NaN
# 156         5326          5326          309862  2010   18326      3      NaN
# 171         5474          5474          310010  2010   18435      3      NaN
# 271         6233          6233          312090  2010   19482      3      NaN
# ...

# %%
unem.groupby('LastYearOCC')['count'].sum()
# Out:
# LastYearOCC
# q1    143
# q2     97
# q3     34
# q4     46
# Name: count, dtype: int64

# %%
# Same OCC
same = data[(~data['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22])) & (data['OCC'] == data['OCCLY'])]

# %%
same.loc[:, ['OCC', 'OCCLY']]
# Out:
#        OCC   OCCLY
# 1     9620  9620.0
# 2     9120  9120.0
# 4     9130  9130.0
# 6     8800  8800.0
# 8     4040  4040.0
# 10    9130  9130.0
# 12    9130  9130.0
# 13    4220  4220.0
# 14    4020  4020.0
# 16    4030  4030.0
# 18    4060  4060.0
# 20    9140  9140.0
# 22    9640  9640.0
# 23    6200  6200.0
# 26    4720  4720.0
# 28    4220  4220.0
# 29    9600  9600.0
# 30    9600  9600.0
# 33    9620  9620.0
# 34    9130  9130.0
# 36    4220  4220.0
# 39    6200  6200.0
# 40    9120  9120.0
# 41    9600  9600.0
# 43    9130  9130.0
# 44    4720  4720.0
# 47    4220  4220.0
# 48    4250  4250.0
# 49    4720  4720.0
# 51    4110  4110.0
# ...    ...     ...
# 2081  3645  3645.0
# 2083  3255  3255.0
# 2084  2310  2310.0
# 2085  2310  2310.0
# 2086  3255  3255.0
# 2087   430   430.0
# 2089  3255  3255.0
# 2090  2310  2310.0
# 2094  2200  2200.0
# 2096  2040  2040.0
# 2099    50    50.0
# 2100    50    50.0
# 2102  3255  3255.0
# 2103  3255  3255.0
# 2104   430   430.0
# ...

# %%
len(same)
# Out:
# 6500

# %%
same
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 1           3650          3650          306603  2010   16895      3      NaN
# 2           3652          3652          306605  2010   16896      3      NaN
# 4           3660          3660          306613  2010   16901      3      NaN
# 6           3672          3672          306625  2010   16908      3      NaN
# 8           3684          3684          306637  2010   16918      3      NaN
# 10          3691          3691          306644  2010   16921      3      NaN
# 12          3712          3712          306665  2010   16931      3      NaN
# 13          3718          3718          306671  2010   16935      3      NaN
# 14          3748          3748          306701  2010   16942      3      NaN
# 16          3754          3754          306707  2010   16943      3      NaN
# 18          3764          3764          306717  2010   16944      3      NaN
# ...

# %%
same.groupby('LastYearOCC')['count'].sum()
# Out:
# LastYearOCC
# q1    1813
# q2    1455
# q3    1415
# q4    1817
# Name: count, dtype: int64

# %%
# Different Job
diff =data[(~data['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22])) & (data['OCC'] != data['OCCLY'])]

# %%
diff
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 17          3755          3755          306708  2010   16943      3      NaN
# 24          3812          3812          308268  2010   17628      3      NaN
# 27          3870          3870          308326  2010   17656      3      NaN
# 68          4223          4223          308759  2010   17846      3      NaN
# 102         4584          4584          309120  2010   17999      3      NaN
# 164         5397          5397          309933  2010   18379      3      NaN
# 166         5423          5423          309959  2010   18395      3      NaN
# 177         5517          5517          310053  2010   18461      3      NaN
# 219         5838          5838          310374  2010   18664      3      NaN
# 238         5998          5998          311620  2010   19276      3      NaN
# 241         6024          6024          311646  2010   19286      3      NaN
# ...

# %%
diff.groupby('LastYearOCC')['count'].sum()
# Out:
# LastYearOCC
# q1    229
# q2    169
# q3    128
# q4    141
# Name: count, dtype: int64

# %%
diff.AGE.value_counts().sort_index()
# Out:
# 18     9
# 19    11
# 20     7
# 21    17
# 22    23
# 23    19
# 24    27
# 25    28
# 26    18
# 27    17
# 28    17
# 29    17
# 30    19
# 31    19
# 32    19
# 33    14
# 34    12
# 35    16
# 36    11
# 37    11
# 38    22
# 39    17
# 40    12
# 41    13
# 42    12
# 43    17
# 44    16
# 45    23
# 46    14
# 47     9
# 48    14
# 49    23
# 50    11
# 51    17
# 52    13
# 53    22
# 54    16
# 55    16
# 56    11
# 57    11
# 58    12
# 59     7
# 60     8
# Name: AGE, dtype: int64
