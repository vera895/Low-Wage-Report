# %%
import pandas as pd
q1_q4_list = pd.read_excel('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1/Q1_Q4_occ_List_averaged.xlsx')
code_name = pd.read_excel('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1/occ_name_merge_codes2.xlsx')

# %%
q1_occ_name = pd.merge(q1_q4_list, code_name, how ='left', left_on = 'OCC_q1', right_on ='occ_code')
q1_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q1_name_merge = q1_occ_name.merged_occ_name.value_counts()
q1_name_merge = pd.DataFrame(q1_name_merge)
q1_name_merge.columns = ['occ_q1_name_merge']
q1_name_merge
# Out:
#                                                     occ_q1_name_merge
# Food Preparation and Serving Occupations                            8
# Construction Trades                                                 8
# Transportation and Material Moving Occupations                      7
# Production Occupations                                              7
# Office and Administrative Support Occupations                       5
# Installation, Maintenance, and Repair Workers                       4
# Sales Occupations                                                   3
# Building and Grounds Cleaning and Maintenance O...                  3
# Protective Service Occupations                                      3
# Personal Care and Service Occupations                               1
# Life, Physical, and Social Science Occupations                      1
# Financial Specialists                                               1
# ...

# %%
q1_name_detail = q1_occ_name.occ_name_detail.value_counts()
q1_name_detail = pd.DataFrame(q1_name_detail)
q1_name_detail.columns = ['occ_q1_name_detail']
q1_name_detail
# Out:
#                                                     occ_q1_name_detail
# Electrical, Electronics, and Electromechanical ...                   1
# Food Preparation Workers                                             1
# Bus Drivers                                                          1
# Travel Agents                                                        1
# Janitors and Building Cleaners                                       1
# Bailiffs, Correctional Officers, and Jailers                         1
# Hazardous Materials                                                  1
# First-Line Supervisors/Managers of Construction...                   1
# Construction Laborers                                                1
# Cooks                                                                1
# Painters, Construction and Maintenance                               1
# Shipping, Receiving, and Traffic Clerks                              1
# ...

# %%
q1_name_detail.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1/q1_q4_occ_name_code/q1_name_detail.csv')
q1_name_merge.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1/q1_q4_occ_name_code/q1_name_merge.csv')

# %% [markdown]
# # Q2

# %%
q2_occ_name = pd.merge(q1_q4_list, code_name, how ='left', left_on = 'OCC_q2', right_on ='occ_code')
q2_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q2_name_merge = q2_occ_name.merged_occ_name.value_counts()
q2_name_merge = pd.DataFrame(q2_name_merge)
q2_name_merge.columns = ['occ_q2_name_merge']
q2_name_merge
# Out:
#                                                     occ_q2_name_merge
# Office and Administrative Support Occupations                      17
# Production Occupations                                              7
# Construction Trades                                                 6
# Sales Occupations                                                   3
# Installation, Maintenance, and Repair Workers                       3
# Healthcare Support Occupations                                      2
# Education, Training, and Library Occupations                        2
# Management Occupations                                              2
# Building and Grounds Cleaning and Maintenance O...                  1
# Arts, Design, Entertainment, Sports, and Media ...                  1
# Healthcare Practitioners and Technical Occupations                  1
# Computer and Mathematical Occupations                               1
# ...

# %%
q2_name_detail = q2_occ_name.occ_name_detail.value_counts()
q2_name_detail = pd.DataFrame(q2_name_detail)
q2_name_detail.columns = ['occ_q2_name_detail']
q2_name_detail
# Out:
#                                                     occ_q2_name_detail
# Insurance Sales Agents                                               1
# Cost Estimators                                                      1
# Sales Representatives, Services, All Other                           1
# Postal Service Mail Sorters, Processors, and Pr...                   1
# Payroll and Timekeeping Clerks                                       1
# Personal and Home Care Aides                                         1
# Nursing, Psychiatric, and Home Health Aides                          1
# Miscellaneous Construction Equipment Operators                       1
# Billing and Posting Clerks and Machine Operators                     1
# Telecommunications Line Installers and Repairers                     1
# Dental Assistants                                                    1
# Stock Clerks and Order Filers                                        1
# ...

# %%
q2_name_detail.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_q1/q1_q4_occ_name_code/q2_name_detail.csv')
q2_name_merge.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_q1/q1_q4_occ_name_code/q2_name_merge.csv')

# %% [markdown]
# # Q3

# %%
q3_occ_name = pd.merge(q1_q4_list, code_name, how ='left', left_on = 'OCC_q3', right_on ='occ_code')
q3_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q3_name_merge = q3_occ_name.merged_occ_name.value_counts()
q3_name_merge = pd.DataFrame(q3_name_merge)
q3_name_merge.columns = ['occ_q3_name_merge']
q3_name_merge
# Out:
#                                                     occ_q3_name_merge
# Management Occupations                                              7
# Sales Occupations                                                   5
# Healthcare Practitioners and Technical Occupations                  4
# Office and Administrative Support Occupations                       4
# Arts, Design, Entertainment, Sports, and Media ...                  4
# Production Occupations                                              3
# Community and Social Services Occupations                           3
# Transportation and Material Moving Occupations                      3
# Financial Specialists                                               3
# Installation, Maintenance, and Repair Workers                       2
# Architecture and Engineering Occupations                            2
# Protective Service Occupations                                      2
# ...

# %%
q3_name_detail = q3_occ_name.occ_name_detail.value_counts()
q3_name_detail = pd.DataFrame(q3_name_detail)
q3_name_detail.columns = ['occ_q3_name_detail']
q3_name_detail
# Out:
#                                                     occ_q3_name_detail
# Engineering Technicians, Except Drafters                             1
# Miscellaneous Engineers, Including Agricultural...                   1
# Announcers                                                           1
# Purchasing Managers                                                  1
# Veterinarians                                                        1
# Carpenters                                                           1
# Tax Preparers                                                        1
# First-Line Supervisors/Managers of Mechanics, I...                   1
# Supervisors, Transportation and Material Moving...                   1
# Clinical Laboratory Technologists and Technicians                    1
# First-Line Supervisors/Managers of Food Prepara...                   1
# Computer Programmers                                                 1
# ...

# %%
q3_name_detail.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_q1/q1_q4_occ_name_code/q3_name_detail.csv')
q3_name_merge.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_q1/q1_q4_occ_name_code/q3_name_merge.csv')

# %% [markdown]
# # Q4

# %%
q4_occ_name = pd.merge(q1_q4_list, code_name, how ='left', left_on = 'OCC_q4', right_on ='occ_code')
q4_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q4_name_merge = q4_occ_name.merged_occ_name.value_counts()
q4_name_merge = pd.DataFrame(q4_name_merge)
q4_name_merge.columns = ['occ_q4_name_merge']
q4_name_merge
# Out:
#                                                     occ_q4_name_merge
# Management Occupations                                              9
# Healthcare Practitioners and Technical Occupations                  6
# Architecture and Engineering Occupations                            5
# Life, Physical, and Social Science Occupations                      4
# Education, Training, and Library Occupations                        4
# Financial Specialists                                               4
# Arts, Design, Entertainment, Sports, and Media ...                  2
# Installation, Maintenance, and Repair Workers                       2
# Personal Care and Service Occupations                               2
# Business Operations Specialists                                     2
# Computer and Mathematical Occupations                               1
# Legal Occupations                                                   1
# ...

# %%
q4_name_detail = q4_occ_name.occ_name_detail.value_counts()
q4_name_detail = pd.DataFrame(q4_name_detail)
q4_name_detail.columns = ['occ_q4_name_detail']
q4_name_detail
# Out:
#                                                     occ_q4_name_detail
# Physicians and Surgeons                                              1
# Chiropractors                                                        1
# Electrical and Electronics Engineers                                 1
# Secondary School Teachers                                            1
# Personal Financial Advisors                                          1
# Physical Scientists, All Other                                       1
# Helpers--Installation, Maintenance, and Repair ...                   1
# Lawyers                                                              1
# Chemists and Materials Scientists                                    1
# Computer and Information Systems Managers                            1
# Purchasing Agents, Except Wholesale, Retail, an...                   1
# Psychologists                                                        1
# ...

# %%
q4_name_detail.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_q1/q1_q4_occ_name_code/q4_name_detail.csv')
q4_name_merge.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_q1/q1_q4_occ_name_code/q4_name_merge.csv')

# %% [markdown]
# # use IPUMS CPS occ 2011+

# %%
import pandas as pd
q1_q4_list = pd.read_excel('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Q1_Q4_occ_List_averaged.xlsx')
code_name = pd.read_excel('C:/Users/yfeng/Desktop/IPUMS CPS OCC.xlsx', sheet_name = 'Sheet1')

# %%
q1_q4_list
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
code_name
# Out:
#         occ                                        description
# 0       0.0                               N/A (not applicable)
# 1      10.0                                   Chief executives
# 2      20.0                    General and operations managers
# 3      30.0                                        Legislators
# 4      40.0                Advertising and promotions managers
# 5      50.0                       Marketing and sales managers
# 6      60.0                          Public relations managers
# 7     100.0                   Administrative services managers
# 8     110.0          Computer and information systems managers
# 9     120.0                                 Financial managers
# 10    135.0                 Compensation and Benefits Managers
# 11    136.0                           Human Resources Managers
# 12    137.0                  Training and Development Managers
# 13    140.0                     Industrial production managers
# ...

# %%
q1_occ_name=pd.merge(q1_q4_list, code_name, how ='left', left_on = 'OCC_q1', right_on ='occ')
q1_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q2_occ_name=pd.merge(q1_occ_name, code_name, how ='left', left_on = 'OCC_q2', right_on ='occ')
q2_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q3_occ_name=pd.merge(q2_occ_name, code_name, how ='left', left_on = 'OCC_q3', right_on ='occ')
q3_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q4_occ_name=pd.merge(q3_occ_name, code_name, how ='left', left_on = 'OCC_q4', right_on ='occ')
q4_occ_name
# Out:
#     OCC_q1  index_score  OCC_q2  index_score.1  OCC_q3  index_score.2  OCC_q4  \
# 0      840    -5.702737   160.0      -0.682811    40.0       0.339430      10
# 1     1740    -4.165192   410.0      -1.265214   100.0       0.369828      20
# 2     2160    -1.577325   600.0      -0.779436   120.0       0.713293      50
# 3     3800    -1.956450  1060.0      -0.558796   140.0       0.849347     110
# 4     3910    -2.063873  1107.0      -0.398063   150.0       0.007283     135
# 5     3930    -2.529432  1920.0      -0.648771   310.0      -0.276829     136
# 6     3940    -1.981520  2025.0      -0.322833   420.0       0.644696     220
# 7     4000    -2.967667  2330.0      -0.285367   520.0       0.248085     230
# 8     4020    -2.078998  2440.0      -1.314767   540.0       0.096166     300
# 9     4030    -1.713409  2750.0      -1.105165   640.0       0.050196     350
# 10    4040    -3.709820  3245.0      -0.429330   860.0       0.190027     425
# ...

# %%
q4_occ_name.to_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q1_q4_occ_name_10_10.csv')

# %%
q4_occ_name.to_excel('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q1_q4_occ_name_10_10.xlsx')
