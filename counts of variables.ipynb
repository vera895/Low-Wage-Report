# %%
import pandas as pd
df = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/All_obs_10counties_presitige.csv')

# %%
df = df.loc[(df['AGE']>= 18)& (df['AGE']<=60)]

# %%
df.INCTOT.value_counts().sort_index()
# Out:
# -9999.0          5
# -9991.0          1
# -9985.0          1
# -9846.0          1
# -2999.0          1
# -2000.0          3
# -1693.0          1
# -1000.0          1
# -500.0           1
# -153.0           1
#  0.0          1246
#  1.0            24
#  2.0            17
#  3.0             9
#  4.0             2
#  5.0            14
#  6.0             4
#  7.0             3
#  8.0             3
#  10.0            8
#  11.0            6
#  12.0            2
#  13.0            1
#  14.0            1
#  15.0            1
#  16.0            5
#  17.0            2
#  18.0            2
#  20.0            4
#  21.0            6
#               ...
#  423711.0        1
#  430000.0        1
#  433715.0        1
#  441364.0        1
#  456700.0        1
#  474999.0        1
#  500145.0        1
#  500349.0        1
#  500640.0        1
#  500943.0        1
#  501600.0        1
#  504457.0        1
#  505134.0        1
#  506370.0        1
#  506460.0        1
#  524500.0        1
# ...

# %%
import numpy as np
d1 = df
d1.loc[d1['INCTOT'].isin([-9999, 0,99999999.0]), 'INCTOT'] =np.nan

# %%
d1 = d1[d1['INCTOT'].notnull()]

# %%
d1
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 3646          3646        306599  2010   16894      3      NaN
# 3647          3647        306600  2010   16894      3      NaN
# 3648          3648        306601  2010   16894      3      NaN
# 3649          3649        306602  2010   16895      3      NaN
# 3650          3650        306603  2010   16895      3      NaN
# 3652          3652        306605  2010   16896      3      NaN
# 3653          3653        306606  2010   16898      3      NaN
# 3654          3654        306607  2010   16898      3      NaN
# 3659          3659        306612  2010   16900      3      NaN
# 3660          3660        306613  2010   16901      3      NaN
# 3663          3663        306616  2010   16903      3      NaN
# 3664          3664        306617  2010   16903      3      NaN
# 3668          3668        306621  2010   16906      3      NaN
# 3669          3669        306622  2010   16908      3      NaN
# ...

# %%
d1.UHRSWORKT.value_counts().sort_index()
# Out:
# 0         7
# 1         2
# 2         5
# 3         6
# 4        13
# 5        15
# 6        18
# 7         4
# 8        37
# 9         7
# 10       63
# 11        2
# 12       37
# 13        6
# 14       10
# 15       87
# 16       52
# 17        6
# 18       24
# 19        3
# 20      262
# 21       12
# 22        8
# 23       12
# 24       66
# 25      113
# 26       13
# 27        7
# 28       32
# 29        3
#        ...
# 55      144
# 56       22
# 57        6
# 58        9
# 59        2
# 60      265
# 62        8
# 63        6
# 64        8
# 65       38
# 66        5
# 68        3
# 70       63
# 72        8
# 73        2
# 75       10
# 76        6
# 78        5
# 79        1
# 80       32
# 82        1
# 84        3
# 85        3
# 90        4
# 99        4
# 100       2
# 109       1
# 140       1
# 997     509
# 999    2267
# Name: UHRSWORKT, Length: 85, dtype: int64

# %%
d1.loc[d1['UHRSWORKT'].isin([997,999,0]), 'UHRSWORKT']= np.nan
d1 = d1.loc[d1['UHRSWORKT'].notnull()]
d1
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 3647          3647        306600  2010   16894      3      NaN
# 3648          3648        306601  2010   16894      3      NaN
# 3650          3650        306603  2010   16895      3      NaN
# 3652          3652        306605  2010   16896      3      NaN
# 3653          3653        306606  2010   16898      3      NaN
# 3654          3654        306607  2010   16898      3      NaN
# 3659          3659        306612  2010   16900      3      NaN
# 3660          3660        306613  2010   16901      3      NaN
# ...

# %%
len(d1)
# Out:
# 7852

# %%
d1.loc[:, ['UHRSWORKT','INCTOT']]
# Out:
#         UHRSWORKT    INCTOT
# 3647         50.0   60000.0
# 3648         60.0   30000.0
# 3650         40.0   23350.0
# 3652         52.0   90337.0
# 3653         40.0   11700.0
# 3654         40.0   23000.0
# 3659         40.0   60700.0
# 3660         46.0   56050.0
# 3663         45.0   30004.0
# 3664         40.0   45001.0
# 3669         40.0   41000.0
# 3672         40.0   33000.0
# 3674         30.0   10264.0
# 3675         45.0   45931.0
# 3676         58.0   71977.0
# 3677         39.0   60000.0
# 3678         40.0   35100.0
# 3679         40.0   32100.0
# 3681         60.0   40010.0
# 3684         45.0   17000.0
# 3687         20.0   19100.0
# 3690         20.0   10605.0
# 3693         37.0   69897.0
# 3694         24.0    7580.0
# 3696         40.0   38616.0
# 3697         40.0   30000.0
# 3699         45.0   60455.0
# 3700         32.0   40005.0
# 3703         16.0    7537.0
# 3707         40.0   30500.0
# ...           ...       ...
# 177607       40.0   60404.0
# ...

# %%
# d12
d1 = df
d1.loc[d1['INCTOT'].isin([-9999, 0,99999999.0]), 'INCTOT'] =np.nan
d1 = d1[d1['INCTOT'].notnull()]

# %%
d1.loc[d1['WKSWORK1']==0, 'WKSWORK1']=np.nan
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d12 = d1.loc[d1['WKSWORK1'].notnull()]

# %%
len(d12)
# Out:
# 9117

# %%
d12.loc[:, ['WKSWORK1','INCTOT']]
# Out:
#         WKSWORK1    INCTOT
# 3646        52.0   19200.0
# 3647        52.0   60000.0
# 3648        40.0   30000.0
# 3650        32.0   23350.0
# 3652        52.0   90337.0
# 3653        52.0   11700.0
# 3654        52.0   23000.0
# 3659        52.0   60700.0
# 3660        52.0   56050.0
# 3663        52.0   30004.0
# 3664        52.0   45001.0
# 3669        52.0   41000.0
# 3672        52.0   33000.0
# 3674        50.0   10264.0
# 3675        52.0   45931.0
# 3676        52.0   71977.0
# 3677        52.0   60000.0
# 3678        52.0   35100.0
# 3679        52.0   32100.0
# 3681        52.0   40010.0
# 3684        52.0   17000.0
# 3685        35.0   20000.0
# 3687        52.0   19100.0
# 3690        43.0   10605.0
# 3691        52.0   30715.0
# 3693        52.0   69897.0
# 3694        40.0    7580.0
# 3696        52.0   38616.0
# 3697        52.0   30000.0
# 3699        33.0   60455.0
# ...          ...       ...
# 177612      52.0   28000.0
# 177613      52.0   45000.0
# ...

# %%
# d13
d1.INCTOT.value_counts().sort_index()
# Out:
# -9991.0        1
# -9985.0        1
# -9846.0        1
# -2999.0        1
# -2000.0        3
# -1693.0        1
# -1000.0        1
# -500.0         1
# -153.0         1
#  1.0          24
#  2.0          17
#  3.0           9
#  4.0           2
#  5.0          14
#  6.0           4
#  7.0           3
#  8.0           3
#  10.0          8
#  11.0          6
#  12.0          2
#  13.0          1
#  14.0          1
#  15.0          1
#  16.0          5
#  17.0          2
#  18.0          2
#  20.0          4
#  21.0          6
#  23.0          1
#  25.0          5
#               ..
#  423711.0      1
#  430000.0      1
#  433715.0      1
#  441364.0      1
#  456700.0      1
#  474999.0      1
#  500145.0      1
#  500349.0      1
#  500640.0      1
#  500943.0      1
#  501600.0      1
#  504457.0      1
#  505134.0      1
#  506370.0      1
#  506460.0      1
#  524500.0      1
#  545150.0      1
#  550050.0      1
#  703121.0      1
#  780000.0      1
#  801550.0      1
# ...

# %%
d1[d1['INCTOT'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, YEAR, SERIAL, MONTH, HWTFINL, CPSID, ASECFLAG, HFLAG, ASECWTH, STATEFIP, COUNTY, PERNUM, WTFINL, CPSIDP, ASECWT, AGE, SEX, RACE, MARST, EMPSTAT, OCC, OCC2010_x, IND, CLASSWKR, UHRSWORKT, EDUC, EDUC99, EDDIPGED, OCCLY, INDLY, OCC90LY, IND90LY, OCC10LY, CLASSWLY, WORKLY, WKSWORK1, UHRSWORKLY, WKSUNEM1, WKXPNS, INCTOT, INCWAGE, PAIDGH, EMCONTRB, JTOCC, HOURWAGE, EARNWEEK, UHRSWORKORG, WKSWORKORG, OCC2010_y, PRESGL, PRENT]
# Index: []
#
# [0 rows x 52 columns]

# %%
d1
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 3646          3646        306599  2010   16894      3      NaN
# 3647          3647        306600  2010   16894      3      NaN
# 3648          3648        306601  2010   16894      3      NaN
# 3649          3649        306602  2010   16895      3      NaN
# 3650          3650        306603  2010   16895      3      NaN
# 3652          3652        306605  2010   16896      3      NaN
# 3653          3653        306606  2010   16898      3      NaN
# 3654          3654        306607  2010   16898      3      NaN
# 3659          3659        306612  2010   16900      3      NaN
# 3660          3660        306613  2010   16901      3      NaN
# 3663          3663        306616  2010   16903      3      NaN
# 3664          3664        306617  2010   16903      3      NaN
# 3668          3668        306621  2010   16906      3      NaN
# 3669          3669        306622  2010   16908      3      NaN
# ...

# %%
d1['UHRSWORKLY'].value_counts().sort_index()
# Out:
# 1.0         3
# 2.0         7
# 3.0        10
# 4.0        22
# 5.0        15
# 6.0        34
# 7.0         8
# 8.0        45
# 9.0         6
# 10.0       91
# 11.0        1
# 12.0       50
# 13.0        8
# 14.0       12
# 15.0      127
# 16.0       51
# 17.0        8
# 18.0       28
# 19.0        4
# 20.0      389
# 21.0       12
# 22.0       10
# 23.0       15
# 24.0       85
# 25.0      181
# 26.0        6
# 27.0       11
# 28.0       25
# 30.0      293
# 31.0        5
#          ...
# 49.0        7
# 50.0      629
# 52.0       74
# 53.0        5
# 54.0        7
# 55.0      154
# 56.0       16
# 57.0        1
# 58.0        8
# 60.0      309
# 62.0        3
# 63.0        6
# 64.0        4
# 65.0       45
# 66.0        1
# 67.0        1
# 68.0        4
# 70.0       71
# 72.0        8
# 73.0        1
# 74.0        1
# 75.0       17
# 76.0        4
# 78.0        1
# 80.0       32
# 84.0        3
# 88.0        2
# 90.0        3
# 99.0        7
# 999.0    1518
# ...

# %%
d1.loc[d1['UHRSWORKLY']==999, 'UHRSWORKLY']=np.nan
d13 = d1.loc[d1['UHRSWORKLY'].notnull()]
d13
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 3646          3646        306599  2010   16894      3      NaN
# 3647          3647        306600  2010   16894      3      NaN
# 3648          3648        306601  2010   16894      3      NaN
# 3650          3650        306603  2010   16895      3      NaN
# 3652          3652        306605  2010   16896      3      NaN
# 3653          3653        306606  2010   16898      3      NaN
# 3654          3654        306607  2010   16898      3      NaN
# 3659          3659        306612  2010   16900      3      NaN
# ...

# %%
d13['UHRSWORKLY'].value_counts().sort_index()
# Out:
# 1.0       3
# 2.0       7
# 3.0      10
# 4.0      22
# 5.0      15
# 6.0      34
# 7.0       8
# 8.0      45
# 9.0       6
# 10.0     91
# 11.0      1
# 12.0     50
# 13.0      8
# 14.0     12
# 15.0    127
# 16.0     51
# 17.0      8
# 18.0     28
# 19.0      4
# 20.0    389
# 21.0     12
# 22.0     10
# 23.0     15
# 24.0     85
# 25.0    181
# 26.0      6
# 27.0     11
# 28.0     25
# 30.0    293
# 31.0      5
#        ...
# 48.0     79
# 49.0      7
# 50.0    629
# 52.0     74
# 53.0      5
# 54.0      7
# 55.0    154
# 56.0     16
# 57.0      1
# 58.0      8
# 60.0    309
# 62.0      3
# 63.0      6
# 64.0      4
# 65.0     45
# 66.0      1
# 67.0      1
# 68.0      4
# 70.0     71
# 72.0      8
# 73.0      1
# 74.0      1
# 75.0     17
# 76.0      4
# 78.0      1
# 80.0     32
# 84.0      3
# 88.0      2
# 90.0      3
# 99.0      7
# Name: UHRSWORKLY, Length: 76, dtype: int64

# %%
d13.loc[d13['UHRSWORKLY'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, YEAR, SERIAL, MONTH, HWTFINL, CPSID, ASECFLAG, HFLAG, ASECWTH, STATEFIP, COUNTY, PERNUM, WTFINL, CPSIDP, ASECWT, AGE, SEX, RACE, MARST, EMPSTAT, OCC, OCC2010_x, IND, CLASSWKR, UHRSWORKT, EDUC, EDUC99, EDDIPGED, OCCLY, INDLY, OCC90LY, IND90LY, OCC10LY, CLASSWLY, WORKLY, WKSWORK1, UHRSWORKLY, WKSUNEM1, WKXPNS, INCTOT, INCWAGE, PAIDGH, EMCONTRB, JTOCC, HOURWAGE, EARNWEEK, UHRSWORKORG, WKSWORKORG, OCC2010_y, PRESGL, PRENT]
# Index: []
#
# [0 rows x 52 columns]

# %%
len(d13)
# Out:
# 9117

# %%
d13.loc[:, ['INCTOT','UHRSWORKLY']]
# Out:
#           INCTOT  UHRSWORKLY
# 3646     19200.0        20.0
# 3647     60000.0        50.0
# 3648     30000.0        40.0
# 3650     23350.0        40.0
# 3652     90337.0        50.0
# 3653     11700.0        40.0
# 3654     23000.0        40.0
# 3659     60700.0        40.0
# 3660     56050.0        46.0
# 3663     30004.0        45.0
# 3664     45001.0        40.0
# 3669     41000.0        40.0
# 3672     33000.0        40.0
# 3674     10264.0        10.0
# 3675     45931.0        40.0
# 3676     71977.0        42.0
# 3677     60000.0        38.0
# 3678     35100.0        40.0
# 3679     32100.0        40.0
# 3681     40010.0        60.0
# 3684     17000.0        45.0
# 3685     20000.0        50.0
# 3687     19100.0        20.0
# 3690     10605.0        20.0
# 3691     30715.0        40.0
# 3693     69897.0        37.0
# 3694      7580.0        11.0
# 3696     38616.0        40.0
# 3697     30000.0        40.0
# 3699     60455.0        40.0
# ...          ...         ...
# ...

# %%
# d14
d1['WKSUNEM1'].value_counts().sort_index()
# Out:
# 0.0     1187
# 1.0       27
# 2.0       34
# 3.0       10
# 4.0       53
# 5.0       11
# 6.0       27
# 7.0       17
# 8.0       52
# 9.0       10
# 10.0      21
# 11.0       3
# 12.0     117
# 13.0      16
# 14.0       7
# 15.0       3
# 16.0      37
# 17.0      19
# 18.0       7
# 19.0       5
# 20.0      36
# 22.0      28
# 23.0       1
# 24.0      16
# 25.0       2
# 26.0      64
# 27.0      12
# 28.0      30
# 30.0      10
# 32.0      35
# 34.0       6
# 35.0       6
# 36.0      29
# 37.0       6
# 38.0       8
# 39.0       9
# 40.0      28
# 41.0       1
# 42.0      11
# 43.0       3
# 44.0      23
# 45.0       3
# 46.0      14
# 47.0       3
# 48.0      12
# 49.0       5
# 50.0       7
# 51.0       5
# 99.0    8559
# Name: WKSUNEM1, dtype: int64

# %%
d1.loc[d1['WKSUNEM1'].isin([0,99]), 'WKSUNEM1']= np.nan
d14 = d1.loc[d1['WKSUNEM1'].notnull()]
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d14.loc[:, ['WKSUNEM1', 'INCTOT']]
# Out:
#         WKSUNEM1   INCTOT
# 3685        17.0  20000.0
# 3699        19.0  60455.0
# 3728         4.0  15012.0
# 3771        32.0  11375.0
# 3776        12.0  43264.0
# 3870        28.0  28050.0
# 3911        12.0  29000.0
# 3928         4.0   5300.0
# 3935        40.0  15180.0
# 3939        28.0  50000.0
# 3945         1.0  12000.0
# 3956        18.0  37622.0
# 3973        46.0  58000.0
# 3990        12.0  10325.0
# 4009        44.0  11603.0
# 4010        20.0   7096.0
# 4062        12.0  54100.0
# 4155         1.0  11053.0
# 4210         1.0   2030.0
# 4223        12.0  15800.0
# 4253        36.0  14316.0
# 4333        12.0  10800.0
# 4360         4.0  25459.0
# 4375        12.0  62362.0
# 4380         7.0  82750.0
# 4389        44.0  14387.0
# 4395         1.0   2000.0
# 4477        10.0  50361.0
# 4481        26.0   2530.0
# 4553        44.0   8600.0
# ...          ...      ...
# 176819       4.0  28000.0
# 176853      12.0  26400.0
# 176875       6.0  59249.0
# ...

# %%
len(d14)
# Out:
# 889

# %%
# d21
d2 = df
d2['INCWAGE'].value_counts().sort_index()
# Out:
# 0.0          3100
# 40.0            1
# 78.0            1
# 85.0            1
# 99.0            1
# 100.0           1
# 150.0           4
# 170.0           1
# 180.0           1
# 200.0           5
# 210.0           1
# 238.0           1
# 250.0           2
# 300.0          14
# 315.0           1
# 325.0           1
# 350.0           1
# 360.0           1
# 384.0           1
# 400.0           4
# 414.0           1
# 450.0           2
# 480.0           2
# 485.0           1
# 500.0          16
# 513.0           1
# 550.0           1
# 572.0           1
# 580.0           1
# 600.0          15
#              ...
# 274766.0        1
# 280000.0        8
# 285000.0        1
# 300000.0       27
# 310000.0        3
# 320000.0        3
# 330000.0        1
# 335000.0        1
# 340000.0        2
# 350000.0        4
# 355000.0        1
# 360000.0        1
# 390000.0        1
# 400000.0       10
# 409068.0        8
# 415929.0        1
# 420000.0        1
# 427000.0        1
# 430000.0        1
# ...

# %%
d2.loc[d2['INCWAGE'].isin([0, 9999999.0 ]), 'INCWAGE']= np.nan

# %%
d21 = d2.loc[d2['INCWAGE'].notnull()]

# %%
d21
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 3646          3646        306599  2010   16894      3      NaN
# 3648          3648        306601  2010   16894      3      NaN
# 3650          3650        306603  2010   16895      3      NaN
# 3652          3652        306605  2010   16896      3      NaN
# 3653          3653        306606  2010   16898      3      NaN
# 3654          3654        306607  2010   16898      3      NaN
# 3659          3659        306612  2010   16900      3      NaN
# 3660          3660        306613  2010   16901      3      NaN
# 3663          3663        306616  2010   16903      3      NaN
# 3664          3664        306617  2010   16903      3      NaN
# 3669          3669        306622  2010   16908      3      NaN
# 3672          3672        306625  2010   16908      3      NaN
# 3674          3674        306627  2010   16910      3      NaN
# 3675          3675        306628  2010   16910      3      NaN
# ...

# %%
d21[d21.INCWAGE.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, YEAR, SERIAL, MONTH, HWTFINL, CPSID, ASECFLAG, HFLAG, ASECWTH, STATEFIP, COUNTY, PERNUM, WTFINL, CPSIDP, ASECWT, AGE, SEX, RACE, MARST, EMPSTAT, OCC, OCC2010_x, IND, CLASSWKR, UHRSWORKT, EDUC, EDUC99, EDDIPGED, OCCLY, INDLY, OCC90LY, IND90LY, OCC10LY, CLASSWLY, WORKLY, WKSWORK1, UHRSWORKLY, WKSUNEM1, WKXPNS, INCTOT, INCWAGE, PAIDGH, EMCONTRB, JTOCC, HOURWAGE, EARNWEEK, UHRSWORKORG, WKSWORKORG, OCC2010_y, PRESGL, PRENT]
# Index: []
#
# [0 rows x 52 columns]

# %%
d2 = d21

# %%
d2.UHRSWORKT.value_counts().sort_index()
# Out:
# 0        7
# 1        1
# 2        5
# 3        5
# 4       12
# 5       13
# 6       14
# 7        4
# 8       33
# 9        6
# 10      54
# 11       2
# 12      33
# 13       6
# 14      10
# 15      79
# 16      46
# 17       4
# 18      21
# 19       3
# 20     246
# 21      12
# 22       8
# 23      11
# 24      63
# 25     105
# 26      13
# 27       7
# 28      31
# 29       3
#       ...
# 54      10
# 55     134
# 56      21
# 57       6
# 58       9
# 59       2
# 60     243
# 62       8
# 63       5
# 64       8
# 65      36
# 66       5
# 68       3
# 70      56
# 72       6
# 73       2
# 75       7
# 76       4
# 78       3
# 79       1
# 80      26
# 82       1
# 84       3
# 85       3
# 90       1
# 99       4
# 100      2
# 109      1
# 997    427
# 999    820
# Name: UHRSWORKT, Length: 84, dtype: int64

# %%
d2.loc[d2.UHRSWORKT.isin([0,997,999]), 'UHRSWORKT'] = np.nan
d21 = d2.loc[d2['UHRSWORKT'].notnull()]
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d21.loc[:, ['UHRSWORKT', 'INCWAGE']]
# Out:
#         UHRSWORKT   INCWAGE
# 3648         60.0   30000.0
# 3650         40.0   20800.0
# 3652         52.0   90000.0
# 3653         40.0   11000.0
# 3654         40.0   23000.0
# 3659         40.0   31700.0
# 3660         46.0   56000.0
# 3663         45.0   30000.0
# 3664         40.0   45000.0
# 3669         40.0   41000.0
# 3672         40.0   33000.0
# 3674         30.0   10103.0
# 3675         45.0   45831.0
# 3676         58.0   70000.0
# 3677         39.0   60000.0
# 3678         40.0   35000.0
# 3679         40.0   32000.0
# 3681         60.0   40000.0
# 3684         45.0   14000.0
# 3687         20.0   18000.0
# 3690         20.0    9890.0
# 3693         37.0   18000.0
# 3694         24.0    5000.0
# 3696         40.0   38600.0
# 3697         40.0   30000.0
# 3699         45.0   50000.0
# 3700         32.0   40000.0
# 3703         16.0    7200.0
# 3707         40.0   30000.0
# 3708         40.0   25000.0
# ...           ...       ...
# 177606       70.0  110000.0
# ...

# %%
len(d21)
# Out:
# 7532

# %%
# d21
d2[d2.INCWAGE.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, YEAR, SERIAL, MONTH, HWTFINL, CPSID, ASECFLAG, HFLAG, ASECWTH, STATEFIP, COUNTY, PERNUM, WTFINL, CPSIDP, ASECWT, AGE, SEX, RACE, MARST, EMPSTAT, OCC, OCC2010_x, IND, CLASSWKR, UHRSWORKT, EDUC, EDUC99, EDDIPGED, OCCLY, INDLY, OCC90LY, IND90LY, OCC10LY, CLASSWLY, WORKLY, WKSWORK1, UHRSWORKLY, WKSUNEM1, WKXPNS, INCTOT, INCWAGE, PAIDGH, EMCONTRB, JTOCC, HOURWAGE, EARNWEEK, UHRSWORKORG, WKSWORKORG, OCC2010_y, PRESGL, PRENT]
# Index: []
#
# [0 rows x 52 columns]

# %%
d2['WKSWORK1'].value_counts().sort_index()
# Out:
# 1.0       14
# 2.0       18
# 3.0       11
# 4.0       37
# 5.0        5
# 6.0       35
# 7.0       12
# 8.0       66
# 9.0       10
# 10.0      46
# 11.0       3
# 12.0     115
# 13.0      18
# 14.0      14
# 15.0      25
# 16.0      67
# 17.0      15
# 18.0      12
# 19.0       2
# 20.0      84
# 21.0       1
# 22.0      11
# 23.0       1
# 24.0      60
# 25.0      27
# 26.0     133
# 27.0       4
# 28.0      36
# 29.0       4
# 30.0      71
# 31.0       4
# 32.0      48
# 33.0       5
# 34.0      13
# 35.0      41
# 36.0      72
# 37.0       6
# 38.0      15
# 39.0      31
# 40.0     215
# 41.0       5
# 42.0      41
# 43.0      15
# 44.0      75
# 45.0      38
# 46.0      41
# 47.0      11
# 48.0     107
# 49.0      26
# 50.0     158
# 51.0      49
# 52.0    6813
# Name: WKSWORK1, dtype: int64

# %%
d21 = d2[d2['WKSWORK1'].notnull()]

# %%
d21.loc[:, ['WKSWORK1', 'INCWAGE']]
# Out:
#         WKSWORK1   INCWAGE
# 3646        52.0   19000.0
# 3648        40.0   30000.0
# 3650        32.0   20800.0
# 3652        52.0   90000.0
# 3653        52.0   11000.0
# 3654        52.0   23000.0
# 3659        52.0   31700.0
# 3660        52.0   56000.0
# 3663        52.0   30000.0
# 3664        52.0   45000.0
# 3669        52.0   41000.0
# 3672        52.0   33000.0
# 3674        50.0   10103.0
# 3675        52.0   45831.0
# 3676        52.0   70000.0
# 3677        52.0   60000.0
# 3678        52.0   35000.0
# 3679        52.0   32000.0
# 3681        52.0   40000.0
# 3684        52.0   14000.0
# 3685        35.0   10000.0
# 3687        52.0   18000.0
# 3690        43.0    9890.0
# 3691        52.0   30000.0
# 3693        52.0   18000.0
# 3694        40.0    5000.0
# 3696        52.0   38600.0
# 3697        52.0   30000.0
# 3699        33.0   50000.0
# 3700        52.0   40000.0
# ...          ...       ...
# 177607      52.0   60000.0
# 177608      52.0   75000.0
# ...

# %%
len(d21)
# Out:
# 8786

# %%
# d23
d2.UHRSWORKLY.value_counts().sort_index()
# Out:
# 1.0       2
# 2.0       6
# 3.0       9
# 4.0      20
# 5.0      15
# 6.0      31
# 7.0       8
# 8.0      41
# 9.0       6
# 10.0     84
# 11.0      1
# 12.0     48
# 13.0      8
# 14.0     12
# 15.0    115
# 16.0     49
# 17.0      8
# 18.0     27
# 19.0      4
# 20.0    368
# 21.0     12
# 22.0     10
# 23.0     15
# 24.0     83
# 25.0    172
# 26.0      5
# 27.0     11
# 28.0     25
# 30.0    278
# 31.0      5
#        ...
# 47.0      8
# 48.0     76
# 49.0      7
# 50.0    602
# 52.0     72
# 53.0      5
# 54.0      6
# 55.0    143
# 56.0     15
# 57.0      1
# 58.0      8
# 60.0    290
# 62.0      3
# 63.0      5
# 64.0      4
# 65.0     41
# 66.0      1
# 67.0      1
# 68.0      4
# 70.0     61
# 72.0      6
# 73.0      1
# 74.0      1
# 75.0     13
# 76.0      2
# 80.0     26
# 84.0      3
# 88.0      2
# 90.0      2
# 99.0      7
# Name: UHRSWORKLY, Length: 75, dtype: int64

# %%
d23 = d2.loc[d2.UHRSWORKLY.notnull()]

# %%
d23.loc[:, ['UHRSWORKLY', 'INCWAGE']]
# Out:
#         UHRSWORKLY   INCWAGE
# 3646          20.0   19000.0
# 3648          40.0   30000.0
# 3650          40.0   20800.0
# 3652          50.0   90000.0
# 3653          40.0   11000.0
# 3654          40.0   23000.0
# 3659          40.0   31700.0
# 3660          46.0   56000.0
# 3663          45.0   30000.0
# 3664          40.0   45000.0
# 3669          40.0   41000.0
# 3672          40.0   33000.0
# 3674          10.0   10103.0
# 3675          40.0   45831.0
# 3676          42.0   70000.0
# 3677          38.0   60000.0
# 3678          40.0   35000.0
# 3679          40.0   32000.0
# 3681          60.0   40000.0
# 3684          45.0   14000.0
# 3685          50.0   10000.0
# 3687          20.0   18000.0
# 3690          20.0    9890.0
# 3691          40.0   30000.0
# 3693          37.0   18000.0
# 3694          11.0    5000.0
# 3696          40.0   38600.0
# 3697          40.0   30000.0
# 3699          40.0   50000.0
# 3700          32.0   40000.0
# ...            ...       ...
# ...

# %%
len(d23)
# Out:
# 8786

# %%
# d24
d2['WKSUNEM1'].value_counts().sort_index()
# Out:
# 0.0     1121
# 1.0       26
# 2.0       32
# 3.0       10
# 4.0       52
# 5.0       11
# 6.0       26
# 7.0       17
# 8.0       51
# 9.0        9
# 10.0      21
# 11.0       3
# 12.0     115
# 13.0      16
# 14.0       7
# 15.0       3
# 16.0      35
# 17.0      17
# 18.0       7
# 19.0       4
# 20.0      34
# 22.0      27
# 23.0       1
# 24.0      15
# 25.0       2
# 26.0      59
# 27.0      11
# 28.0      28
# 30.0      10
# 32.0      34
# 34.0       5
# 35.0       6
# 36.0      28
# 37.0       6
# 38.0       8
# 39.0       8
# 40.0      27
# 41.0       1
# 42.0      11
# 43.0       3
# 44.0      22
# 45.0       3
# 46.0      13
# 47.0       2
# 48.0      11
# 49.0       3
# 50.0       7
# 51.0       5
# 99.0    6813
# Name: WKSUNEM1, dtype: int64

# %%
d2.loc[d2['WKSUNEM1'].isin([0,99]), 'WKSUNEM1']= np.nan
d24 = d2.loc[d2['WKSUNEM1'].notnull()]
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d24.loc[:, ['WKSUNEM1', 'INCWAGE']]
# Out:
#         WKSUNEM1  INCWAGE
# 3685        17.0  10000.0
# 3699        19.0  50000.0
# 3728         4.0  15000.0
# 3771        32.0   8000.0
# 3776        12.0  34000.0
# 3870        28.0  28000.0
# 3911        12.0  29000.0
# 3928         4.0   5300.0
# 3935        40.0   7000.0
# 3939        28.0  50000.0
# 3945         1.0  12000.0
# 3956        18.0  11002.0
# 3973        46.0  18000.0
# 3990        12.0   9000.0
# 4009        44.0   1600.0
# 4010        20.0   4228.0
# 4062        12.0  54000.0
# 4155         1.0  10000.0
# 4210         1.0   1430.0
# 4223        12.0  15800.0
# 4253        36.0   3202.0
# 4333        12.0  10000.0
# 4360         4.0  25000.0
# 4375        12.0  55000.0
# 4380         7.0  80000.0
# 4389        44.0    500.0
# 4395         1.0   2000.0
# 4477        10.0  45000.0
# 4481        26.0   2530.0
# 4553        44.0   2600.0
# ...          ...      ...
# 176819       4.0  28000.0
# 176853      12.0  20000.0
# 176875       6.0  55000.0
# ...

# %%
len(d24)
# Out:
# 852

# %%
# d31
d3 = df
d3.HOURWAGE.value_counts().sort_index()
# Out:
# 0.00        381
# 1.00          3
# 1.48          2
# 1.89          3
# 2.00          6
# 2.12          1
# 2.13          4
# 2.15          1
# 2.17          1
# 2.22          1
# 2.25          1
# 2.30          1
# 2.33          1
# 2.37          2
# 2.39          1
# 2.50          4
# 2.60          1
# 2.65          1
# 2.70          1
# 2.75          6
# 2.80          4
# 2.83         31
# 2.85          2
# 3.00         15
# 3.25          1
# 3.27          2
# 3.33          4
# 3.38          1
# 3.47          1
# 3.50          3
#           ...
# 56.67         2
# 56.89         2
# 57.00         6
# 57.69         5
# 58.00         4
# 58.25         2
# 58.45         1
# 59.01         2
# 60.00        14
# 60.40         1
# 60.41         1
# 61.00         1
# 62.40         1
# 63.00         1
# 64.00         1
# 65.00         2
# 65.40         1
# 67.00         2
# 68.20         1
# 68.68         1
# 70.00         3
# 70.73         1
# 72.12         9
# 74.00         3
# ...

# %%
d3.loc[d3['HOURWAGE'].isin([0, 99.99, 99.97]), 'HOURWAGE']=np.nan

# %%
d3 = d3[d3['HOURWAGE'].notnull()]

# %%
d3[d3['HOURWAGE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, YEAR, SERIAL, MONTH, HWTFINL, CPSID, ASECFLAG, HFLAG, ASECWTH, STATEFIP, COUNTY, PERNUM, WTFINL, CPSIDP, ASECWT, AGE, SEX, RACE, MARST, EMPSTAT, OCC, OCC2010_x, IND, CLASSWKR, UHRSWORKT, EDUC, EDUC99, EDDIPGED, OCCLY, INDLY, OCC90LY, IND90LY, OCC10LY, CLASSWLY, WORKLY, WKSWORK1, UHRSWORKLY, WKSUNEM1, WKXPNS, INCTOT, INCWAGE, PAIDGH, EMCONTRB, JTOCC, HOURWAGE, EARNWEEK, UHRSWORKORG, WKSWORKORG, OCC2010_y, PRESGL, PRENT]
# Index: []
#
# [0 rows x 52 columns]

# %%
d3.UHRSWORKT.value_counts().sort_index()
# Out:
# 0        9
# 1        3
# 2        8
# 3        8
# 4       21
# 5       19
# 6       24
# 7        9
# 8       57
# 9        9
# 10      97
# 11       1
# 12      73
# 13      10
# 14      15
# 15     121
# 16      99
# 17       8
# 18      41
# 19       2
# 20     467
# 21      15
# 22      20
# 23      17
# 24     142
# 25     246
# 26      18
# 27      24
# 28      56
# 29      15
#       ...
# 53       9
# 54       7
# 55      93
# 56      43
# 57       5
# 58      11
# 59       3
# 60     123
# 61       1
# 62       5
# 63       2
# 64       6
# 65      25
# 66       3
# 68       1
# 69       1
# 70      18
# 72       7
# 73       2
# 75       4
# 76       1
# 77       2
# 78       2
# 79       1
# 80       9
# 84       1
# 90       3
# 96       1
# 100      2
# 997    658
# Name: UHRSWORKT, Length: 83, dtype: int64

# %%
d3.loc[d3['UHRSWORKT'].isin([0,997,999]), 'UHRSWORKT']= np.nan
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d31 = d3[d3['UHRSWORKT'].notnull()]

# %%
d31.loc[:, ['UHRSWORKT', 'HOURWAGE']]
# Out:
#         UHRSWORKT  HOURWAGE
# 6            40.0     20.70
# 76           50.0      9.30
# 84           25.0     30.00
# 100          40.0      7.25
# 102          40.0     14.00
# 103          40.0     25.00
# 117          40.0     16.85
# 119          36.0      7.25
# 138          35.0      7.25
# 142          41.0     33.11
# 192          40.0     22.00
# 201          40.0     19.00
# 248          42.0     38.00
# 249          38.0     13.50
# 250          40.0     32.00
# 271          40.0      9.50
# 273          32.0     12.00
# 285          12.0     35.00
# 318          40.0     12.00
# 321          20.0     37.50
# 322          40.0     38.50
# 344          51.0     39.00
# 349          40.0     16.74
# 433          45.0     20.00
# 436          20.0      7.25
# 469          40.0     12.60
# 470          40.0      8.96
# 487          25.0      5.00
# 488          40.0     12.00
# 531          40.0     18.80
# ...           ...       ...
# 199530       40.0     14.83
# ...

# %%
len(d31)
# Out:
# 9881

# %%
d31
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH    HWTFINL  \
# 6                6          4366  2010    2613      1  3683.7540
# 76              76          4505  2010    2701      1  2635.4699
# 84              84          4513  2010    2704      1  3786.7243
# 100            100          4529  2010    2708      1  2745.0915
# 102            102          4531  2010    2710      1  2544.1069
# 103            103          4532  2010    2710      1  2544.1069
# 117            117          4558  2010    2731      1  3561.0132
# 119            119          4560  2010    2731      1  3561.0132
# 138            138          4634  2010    2777      1  2906.0264
# 142            142          4638  2010    2780      1  2770.8363
# 192            192          4763  2010    2860      1  3075.0249
# 201            201          4772  2010    2867      1  2388.6063
# 248            248         11999  2010    6258      1  3813.9774
# ...

# %%
len(d31.PRESGL.isnull())
# Out:
# 9881

# %%
d31 = d31[d31.PRESGL.notnull()]

# %%
d31
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH    HWTFINL  \
# 76              76          4505  2010    2701      1  2635.4699
# 84              84          4513  2010    2704      1  3786.7243
# 100            100          4529  2010    2708      1  2745.0915
# 102            102          4531  2010    2710      1  2544.1069
# 103            103          4532  2010    2710      1  2544.1069
# 119            119          4560  2010    2731      1  3561.0132
# 138            138          4634  2010    2777      1  2906.0264
# 248            248         11999  2010    6258      1  3813.9774
# 249            249         12000  2010    6258      1  3813.9774
# 250            250         12001  2010    6259      1  3042.7988
# 271            271         12031  2010    6271      1  2861.4301
# 273            273         12033  2010    6272      1  2605.6782
# 318            318         12119  2010    6313      1  3908.7225
# ...

# %%
len(d31)
# Out:
# 9684

# %%
d312 = d31[d31.PAIDGH.notnull()]

# %%
d312
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 3648          3648        306601  2010   16894      3      NaN
# 3650          3650        306603  2010   16895      3      NaN
# 3654          3654        306607  2010   16898      3      NaN
# 3659          3659        306612  2010   16900      3      NaN
# 3684          3684        306637  2010   16918      3      NaN
# 3687          3687        306640  2010   16919      3      NaN
# 3771          3771        308227  2010   17607      3      NaN
# 3772          3772        308228  2010   17607      3      NaN
# 3775          3775        308231  2010   17608      3      NaN
# 3777          3777        308233  2010   17609      3      NaN
# 3785          3785        308241  2010   17613      3      NaN
# 3868          3868        308324  2010   17655      3      NaN
# 3870          3870        308326  2010   17656      3      NaN
# 3871          3871        308327  2010   17656      3      NaN
# ...

# %%
len(d312)
# Out:
# 675

# %%
d31.loc[d31.PAIDGH.isnull()]
# Out:
#         Unnamed: 0  Unnamed: 0.1  YEAR  SERIAL  MONTH    HWTFINL  \
# 76              76          4505  2010    2701      1  2635.4699
# 84              84          4513  2010    2704      1  3786.7243
# 100            100          4529  2010    2708      1  2745.0915
# 102            102          4531  2010    2710      1  2544.1069
# 103            103          4532  2010    2710      1  2544.1069
# 119            119          4560  2010    2731      1  3561.0132
# 138            138          4634  2010    2777      1  2906.0264
# 248            248         11999  2010    6258      1  3813.9774
# 249            249         12000  2010    6258      1  3813.9774
# 250            250         12001  2010    6259      1  3042.7988
# 271            271         12031  2010    6271      1  2861.4301
# 273            273         12033  2010    6272      1  2605.6782
# 318            318         12119  2010    6313      1  3908.7225
# ...

# %%
len(d31.loc[d31.PAIDGH.isnull()])
# Out:
# 9009

# %%
# d41 
d4 = df
d4['EARNWEEK'].value_counts().sort_index()
# Out:
# 0.00          25
# 0.01           2
# 0.10           1
# 0.48           1
# 0.50           1
# 1.00           4
# 1.15           1
# 1.19           1
# 1.53           2
# 2.00           1
# 2.40           1
# 2.88           1
# 3.36           1
# 3.65           1
# 3.75           1
# 5.76           1
# 7.25           1
# 10.00          1
# 11.60          1
# 12.00          2
# 12.50          1
# 14.00          1
# 16.00          1
# 19.21          1
# 20.00          3
# 20.32          1
# 22.00          1
# 22.30          1
# 23.00          1
# 23.07          2
#            ...
# 2654.00        1
# 2673.07        3
# 2676.92        1
# 2692.00        8
# 2692.30       25
# 2700.00        3
# 2708.33        1
# 2711.00        1
# 2711.53        2
# 2720.00        1
# 2730.76        1
# 2750.00       10
# 2769.00        3
# 2769.23        5
# 2788.00        2
# 2788.46        8
# 2800.00        4
# 2807.69        1
# 2815.00        3
# 2815.38        1
# 2826.00        1
# ...

# %%
d4.loc[d4['EARNWEEK'].isin([0, 9999.99]), 'EARNWEEK']= np.nan
d4 = d4.loc[d4.EARNWEEK.notnull()]

# %%
d4['UHRSWORKT'].value_counts().sort_index()
# Out:
# 0        13
# 1         3
# 2         8
# 3        11
# 4        30
# 5        25
# 6        27
# 7         9
# 8        68
# 9        10
# 10      116
# 11        2
# 12       79
# 13       10
# 14       18
# 15      146
# 16      105
# 17       10
# 18       44
# 19        4
# 20      563
# 21       17
# 22       24
# 23       18
# 24      167
# 25      288
# 26       19
# 27       27
# 28       61
# 29       16
#        ...
# 60      485
# 61        1
# 62       11
# 63       10
# 64       10
# 65       71
# 66        6
# 67        2
# 68        5
# 69        1
# 70       86
# 72       11
# 73        2
# 74        2
# 75       15
# 76        2
# 77        2
# 78        2
# 79        3
# 80       63
# 84        4
# 85        5
# 86        1
# 87        1
# 90       11
# 96        2
# 99        4
# 100       4
# 125       1
# 997    1048
# Name: UHRSWORKT, Length: 90, dtype: int64

# %%
d4.loc[d4['UHRSWORKT'].isin([0, 997]), 'UHRSWORKT'] = np.nan
d41 = d4[d4.UHRSWORKT.notnull()]
# Out:
# C:\Users\yfeng\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
d41.loc[:, ['EARNWEEK', 'UHRSWORKT']]
# Out:
#         EARNWEEK  UHRSWORKT
# 6         769.23       40.0
# 7         711.53       40.0
# 8         250.00        4.0
# 9        1384.00       40.0
# 76        465.00       50.0
# 83       2500.00       50.0
# 84        800.00       25.0
# 87       2000.00       40.0
# 100       290.00       40.0
# 102       560.00       40.0
# 103      1000.00       40.0
# 117       700.00       40.0
# 118       845.00       45.0
# 119       234.50       36.0
# 138       253.75       35.0
# 141      1634.61       50.0
# 142      1326.92       41.0
# 192       880.00       40.0
# 195       884.61       40.0
# 196       673.07       40.0
# 201       760.00       40.0
# 230       993.69       40.0
# 232      1100.00       40.0
# 248       800.00       42.0
# 249       600.00       38.0
# 250      1280.00       40.0
# 252      2884.61       74.0
# 255       180.00       40.0
# 270       669.00       40.0
# 271       380.00       40.0
# ...          ...        ...
# 199744   1153.84       40.0
# ...
