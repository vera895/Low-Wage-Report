# %%
import pandas as pd
q1 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q1.csv')
q2 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q2.csv')
q3 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q3.csv')
q4 = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/Figure1/figure_q4.csv')

# %% [markdown]
# # Transition in Q1

# %%
q1[q1['EMPSTAT'].isin([30,31,32,33,34,35,36])]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 11          3709          3709          306662  2010   16930      3      NaN
# 25          3834          3834          308290  2010   17635      3      NaN
# 65          4145          4145          308681  2010   17823      3      NaN
# 73          4318          4318          308854  2010   17895      3      NaN
# 80          4389          4389          308925  2010   17921      3      NaN
# 82          4419          4419          308955  2010   17934      3      NaN
# 87          4449          4449          308985  2010   17945      3      NaN
# 94          4509          4509          309045  2010   17963      3      NaN
# 112         4724          4724          309260  2010   18052      3      NaN
# 119         4846          4846          309382  2010   18106      3      NaN
# 161         5380          5380          309916  2010   18363      3      NaN
# ...

# %%
len(q1[q1['EMPSTAT'].notna()])
# Out:
# 2327

# %%
len(q1[q1['OCC'].notna()])
# Out:
# 2327

# %%
len(q1[q1['OCCLY'].notna()])
# Out:
# 2327

# %%
# q1ew: out of labor force:180 obs
len(q1[q1['EMPSTAT'].isin([30,31,32,33,34,35,36])])
# Out:
# 180

# %%
# q1: unemployed:155
len(q1[q1['EMPSTAT'].isin([20,21,22])])
# Out:
# 155

# %%
# same occ: 1762
q1.loc[(q1['OCC']==q1['OCCLY']) & (q1['OCCLY'].notna()) & (~q1['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]))]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 0           3648          3648          306601  2010   16894      3      NaN
# 1           3650          3650          306603  2010   16895      3      NaN
# 2           3652          3652          306605  2010   16896      3      NaN
# 3           3654          3654          306607  2010   16898      3      NaN
# 4           3660          3660          306613  2010   16901      3      NaN
# 5           3669          3669          306622  2010   16908      3      NaN
# 6           3672          3672          306625  2010   16908      3      NaN
# 7           3675          3675          306628  2010   16910      3      NaN
# 8           3684          3684          306637  2010   16918      3      NaN
# 10          3691          3691          306644  2010   16921      3      NaN
# 12          3712          3712          306665  2010   16931      3      NaN
# ...

# %%
# different q1 job
q1_occ = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q1_occ_list.csv')
q1_li = list(q1_occ.values.flatten())

# %%
q1_li
# Out:
# [840,
#  1740,
#  2160,
#  3800,
#  3910,
#  3930,
#  3940,
#  4000,
#  4020,
#  4030,
#  4040,
#  4060,
#  4110,
#  4120,
#  4140,
#  4220,
#  4230,
#  4250,
#  4510,
#  4720,
#  4760,
#  4830,
#  5100,
#  5350,
#  5510,
#  5610,
#  5860,
#  6040,
#  6200,
#  6260,
#  6330,
#  6420,
#  6515,
#  6530,
#  6660,
#  6700,
#  6720,
#  7010,
#  7150,
#  7260,
#  7330,
#  7630,
#  7720,
#  7750,
#  7840,
#  8140,
#  8460,
#  8610,
#  8800,
#  8965,
#  9120,
#  9130,
#  9140,
#  9150,
#  9600,
#  9620,
#  9640]

# %%
q2_occ = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q2_occ_list.csv')
q2_li = list(q2_occ.values.flatten())

# %%
q2_li
# Out:
# [160,
#  410,
#  600,
#  1060,
#  1107,
#  1920,
#  2025,
#  2330,
#  2440,
#  2750,
#  3245,
#  3500,
#  3600,
#  3640,
#  3655,
#  3945,
#  4210,
#  4610,
#  4700,
#  4810,
#  4840,
#  5110,
#  5120,
#  5140,
#  5240,
#  5250,
#  5320,
#  5400,
#  5420,
#  5520,
#  5540,
#  5550,
#  5560,
#  5600,
#  5620,
#  5700,
#  5810,
#  5840,
#  5940,
#  6220,
#  6250,
#  6320,
#  6355,
#  6360,
#  6400,
#  6440,
#  7200,
#  7340,
#  7420,
#  7800,
#  7810,
#  8030,
#  8130,
#  8220,
#  8500,
#  8740]

# %%
q3_occ = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q3_occ_list.csv')
q3_li = list(q3_occ.values.flatten())

# %%
q3_li
# Out:
# [40,
#  100,
#  120,
#  140,
#  150,
#  310,
#  420,
#  520,
#  540,
#  640,
#  860,
#  910,
#  940,
#  1006,
#  1007,
#  1010,
#  1050,
#  1530,
#  1550,
#  2000,
#  2010,
#  2050,
#  2145,
#  2300,
#  2340,
#  2600,
#  2630,
#  2800,
#  2840,
#  3030,
#  3250,
#  3300,
#  3320,
#  3420,
#  3740,
#  3850,
#  4010,
#  4710,
#  4800,
#  4820,
#  4850,
#  4900,
#  4965,
#  5000,
#  5160,
#  5360,
#  5800,
#  6230,
#  7000,
#  7410,
#  7700,
#  7900,
#  8810,
#  9000,
#  9200,
#  9750]

# %%
q4_occ = pd.read_csv('C:/Users/yfeng/Desktop/cps/Sep_17_new_Q1_low_wage_report/q4_occ_list.csv')
q4_li = list(q4_occ.values.flatten())

# %%
q4_li
# Out:
# [10,
#  20,
#  50,
#  110,
#  135,
#  136,
#  220,
#  230,
#  300,
#  350,
#  425,
#  430,
#  530,
#  565,
#  630,
#  650,
#  710,
#  735,
#  740,
#  800,
#  830,
#  850,
#  950,
#  1020,
#  1300,
#  1360,
#  1410,
#  1430,
#  1460,
#  1650,
#  1720,
#  1760,
#  1820,
#  1965,
#  2040,
#  2100,
#  2200,
#  2310,
#  2320,
#  2550,
#  2810,
#  2900,
#  3000,
#  3050,
#  3060,
#  3110,
#  3255,
#  3310,
#  3400,
#  3535,
#  3645,
#  3820,
#  4300,
#  4620,
#  7020,
#  7610,
#  8760]

# %%
q1.loc[~q1['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q1['OCC'].isin(q1_li) &(q1['OCC'] != q1['OCCLY'])]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  SERIAL  MONTH  HWTFINL  \
# 17          3755          3755          306708  2010   16943      3      NaN
# 24          3812          3812          308268  2010   17628      3      NaN
# 27          3870          3870          308326  2010   17656      3      NaN
# 102         4584          4584          309120  2010   17999      3      NaN
# 164         5397          5397          309933  2010   18379      3      NaN
# 177         5517          5517          310053  2010   18461      3      NaN
# 188         5577          5577          310113  2010   18500      3      NaN
# 219         5838          5838          310374  2010   18664      3      NaN
# 241         6024          6024          311646  2010   19286      3      NaN
# 293        28734         28734         2137759  2011   16791      3      NaN
# 294        28735         28735         2137760  2011   16791      3      NaN
# ...

# %%
#  diferent q1 job: 115
len(q1.loc[~q1['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q1['OCC'].isin(q1_li) &(q1['OCC'] != q1['OCCLY'])])
# Out:
# 115

# %%
# different q2 job
len(q1.loc[~q1['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q1['OCC'].isin(q2_li) &(q1['OCC'] != q1['OCCLY'])])
# Out:
# 34

# %%
# different q3 job
len(q1.loc[~q1['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q1['OCC'].isin(q3_li) &(q1['OCC'] != q1['OCCLY'])])
# Out:
# 26

# %%
# different q4 job
len(q1.loc[(~q1['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22])) & (q1['OCC'].isin(q4_li)) &(q1['OCC'] != q1['OCCLY'])])
# Out:
# 12

# %%
180+155+1762+115+34+26+12
# Out:
# 2284

# %% [markdown]
# # q2

# %%
len(q2[q2['EMPSTAT'].notna()])
# Out:
# 1889

# %%
len(q2[q2['OCC'].notna()])
# Out:
# 1889

# %%
len(q2[q2['OCCLY'].notna()])
# Out:
# 1889

# %%
# q2ew: out of labor force:79 obs
len(q2[q2['EMPSTAT'].isin([30,31,32,33,34,35,36])])
# Out:
# 79

# %%
# q2: unemployed:87
len(q2[q2['EMPSTAT'].isin([20,21,22])])
# Out:
# 87

# %%
# same occ: 1542
len(q2.loc[(q2['OCC']==q2['OCCLY']) & (q2['OCCLY'].notna()) & (~q2['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]))])
# Out:
# 1542

# %%
#  diferent q1 job: 115
len(q2.loc[~q2['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q2['OCC'].isin(q1_li) &(q2['OCC'] != q2['OCCLY'])])
# Out:
# 40

# %%
# different q2 job
len(q2.loc[~q2['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q2['OCC'].isin(q2_li) &(q2['OCC'] != q2['OCCLY'])])
# Out:
# 46

# %%
# different q3 job
len(q2.loc[~q2['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q2['OCC'].isin(q3_li) &(q2['OCC'] != q2['OCCLY'])])
# Out:
# 31

# %%
# different q4 job
len(q2.loc[(~q2['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22])) & (q2['OCC'].isin(q4_li)) &(q2['OCC'] != q2['OCCLY'])])
# Out:
# 21

# %%
79+87+1542+40+46+31+21
# Out:
# 1846

# %% [markdown]
# # q3

# %%
len(q3[q3['EMPSTAT'].notna()])
# Out:
# 1496

# %%
len(q3[q3['OCC'].notna()])
# Out:
# 1496

# %%
len(q3[q3['OCCLY'].notna()])
# Out:
# 1496

# %%
# q3ew: out of labor force:44 obs
len(q3[q3['EMPSTAT'].isin([30,31,32,33,34,35,36])])
# Out:
# 44

# %%
# q3: unemployed:43
len(q3[q3['EMPSTAT'].isin([20,21,22])])
# Out:
# 43

# %%
# same occ: 1299
len(q3.loc[(q3['OCC']==q3['OCCLY']) & (q3['OCCLY'].notna()) & (~q3['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]))])
# Out:
# 1299

# %%
#  diferent q1 job: 115
len(q3.loc[~q3['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q3['OCC'].isin(q1_li) &(q3['OCC'] != q3['OCCLY'])])
# Out:
# 17

# %%
# different q2 job
len(q3.loc[~q3['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q3['OCC'].isin(q2_li) &(q3['OCC'] != q3['OCCLY'])])
# Out:
# 18

# %%
# different q3 job
len(q3.loc[~q3['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q3['OCC'].isin(q3_li) &(q3['OCC'] != q3['OCCLY'])])
# Out:
# 20

# %%
# different q4 job
len(q3.loc[(~q3['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22])) & (q3['OCC'].isin(q4_li)) &(q3['OCC'] != q3['OCCLY'])])
# Out:
# 38

# %%
44+43+1299+17+18+20+38
# Out:
# 1479

# %% [markdown]
# # q4

# %%
len(q4[q4['EMPSTAT'].notna()])
# Out:
# 2132

# %%
len(q4[q4['OCC'].notna()])
# Out:
# 2132

# %%
len(q4[q4['OCCLY'].notna()])
# Out:
# 2132

# %%
# q4ew: out of labor force:54 obs
len(q4[q4['EMPSTAT'].isin([30,31,32,33,34,35,36])])
# Out:
# 54

# %%
# q4: unemployed:35
len(q4[q4['EMPSTAT'].isin([20,21,22])])
# Out:
# 35

# %%
# same occ: 1897
len(q4.loc[(q4['OCC']==q4['OCCLY']) & (q4['OCCLY'].notna()) & (~q4['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]))])
# Out:
# 1897

# %%
#  diferent q1 job: 115
len(q4.loc[~q4['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q4['OCC'].isin(q1_li) &(q4['OCC'] != q4['OCCLY'])])
# Out:
# 9

# %%
# different q2 job
len(q4.loc[~q4['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q4['OCC'].isin(q2_li) &(q4['OCC'] != q4['OCCLY'])])
# Out:
# 13

# %%
# different q3 job
len(q4.loc[~q4['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22]) & q4['OCC'].isin(q3_li) &(q4['OCC'] != q4['OCCLY'])])
# Out:
# 51

# %%
# different q4 job
len(q4.loc[(~q4['EMPSTAT'].isin([30,31,32,33,34,35,36,20,21,22])) & (q4['OCC'].isin(q4_li)) &(q4['OCC'] != q4['OCCLY'])])
# Out:
# 43

# %%
54+35+1897+9+13+51+43
# Out:
# 2102
